# %%
import os
from dotenv import load_dotenv

os.environ['OPEN_API_KEY'] = os.getenv("OPENAI_API_KEY")
os.environ['LANGCHAIN_API_KEY'] = os.getenv("LANGCHAIN_API_KEY")
os.environ['LANGCHAIN_TRACING_V2'] = "true"
os.environ['LANGCHAIN_PROJECT'] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model = "gpt-4o")
print(llm)
# Out:
# profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000001E987880390> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001E987881D90> root_client=<openai.OpenAI object at 0x000001E9E21EDD10> root_async_client=<openai.AsyncOpenAI object at 0x000001E987881810> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
result = llm.invoke('what is generative AI?')
print(result)
# Out:
# content="Generative AI refers to a category of artificial intelligence systems designed to generate new content. This can include text, images, music, and other forms of media. The primary characteristic of generative AI is its ability to produce outputs that resemble human-created content, often indistinguishable from it to the casual observer.\n\nKey technologies enabling generative AI include:\n\n1. **Neural Networks**: Specifically, deep learning models such as Generative Adversarial Networks (GANs) and Variational Autoencoders (VAEs) are often used. These systems learn from vast amounts of data to create new data with similar characteristics.\n\n2. **Transformer Models**: Recent advancements, particularly with transformer models like OpenAI's GPT (Generative Pre-trained Transformer) and similar architectures, have revolutionized natural language processing (NLP) by enabling the creation of coherent and contextually relevant text.\n\n3. **Diffusion Models**: These are used for generating high-fidelity images and are behind some of the latest image generation tools.\n\nApplications of generative AI are diverse, ranging from creating realistic images and art to generating human-like text responses, composing music, and even assisting in software development with code generation. While it opens up numerous possibilities for innovation and creativity, generative AI also poses challenges, such as potential misuse for creating misinformation or deepfakes and ethical concerns regarding originality and ownership of AI-generated content." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 281, 'prompt_tokens': 13, 'total_tokens': 294, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_7720ca36e9', 'id': 'chatcmpl-DQvvVjBf0jzAwHn7sT2ON6cfw9p4X', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d58d0-c1af-77f3-9959-8ba6345f3161-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 281, 'total_tokens': 294, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate([
    ("system", "you are an expert AI engineer. Provide me answers based on the question"),
    ("user", "{input}")
])
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='you are an expert AI engineer. Provide me answers based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt|llm
response = chain.invoke({"input": "can you tell me about Langsmith?"}) 
print(response)
# Out:
# content="Langsmith is a toolset designed to enhance the development of applications powered by large language models (LLMs). It streamlines the testing, evaluation, and monitoring processes for these applications. The core functionalities of Langsmith include:\n\n1. **Testing**: Langsmith provides features for systematically testing large language models against a predefined set of inputs and scenarios, allowing developers to ensure that the models perform as expected across different use cases.\n\n2. **Evaluation**: It offers robust evaluation tools to assess the output of LLMs. This includes quality metrics and comparative analysis to gauge the effectiveness, accuracy, and relevance of the model's responses.\n\n3. **Monitoring**: After deployment, Langsmith allows developers to continuously monitor LLMs, offering insights into performance, potential drifts in responses, and other issues that might arise over time. This helps in maintaining the effectiveness of the model throughout its lifecycle.\n\nLangsmith aims to make it easier for developers to build reliable, high-quality applications that leverage the power of large language models by providing a comprehensive suite of tools for quality assurance and maintenance." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 217, 'prompt_tokens': 33, 'total_tokens': 250, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_c8b70290c4', 'id': 'chatcmpl-DQwIh9whoRvsYEV1sGWVqCB6P2Edo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d58e6-af90-72a3-b7cc-9633eeee4f1c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 33, 'output_tokens': 217, 'total_tokens': 250, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
##Stroutput parser
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt|llm|output_parser
response = chain.invoke({"input": "can you tell me about Langsmith?"}) 
print(response)
# Out:
# Langsmith is a suite of tools and services developed by LangChain, designed to facilitate the development, testing, and deployment of language model applications. It provides developers with various features to make the process of building applications with language models more efficient and reliable. Langsmith is particularly useful for tasks such as prompt management, error analysis, version control, and more. This toolkit supports developers in optimizing their applications, improving performance, and ensuring that language models are used effectively to deliver accurate and meaningful results.
