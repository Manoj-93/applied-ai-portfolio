# %%
import numpy as np
k = 2
IVF = [[] for _ in range(k)]
IVF[1].append(4)
IVF[1].append(4)
IVF[1].append(4)
print(IVF)

vp = []
vp.append(1)
vp.append(2)
print(vp)

u = np.array([1.0, 1.1, 5.1, 5.0])
centroids = np.array([
    [0.999, 1.033, 4.9, 5.1],   # centroid for cluster 0  (close to v1, v2, v5)
    [8.9,   9.1,   0.45, 0.65]  # centroid for cluster 1  (close to v3, v4)
])
dist_u = []
for cent in range(k):
  print('centroids[cent]',centroids[cent])
  dist = np.sum((centroids[cent] - u) ** 2)
  dist_u.append(dist)
print(dist_u)
# Out:
# [[], [4, 4, 4]]
# [1, 2]
# centroids[cent] [0.999 1.033 4.9   5.1  ]
# centroids[cent] [8.9  9.1  0.45 0.65]
# [np.float64(0.054489999999999664), np.float64(166.95499999999998)]
