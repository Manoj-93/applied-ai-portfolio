# %% [markdown]
# Analyzing Text Data

# %% [markdown]
# Representing Text as vector
# Bag of words: all the words in the doc can give as something about the document, ignore grammer (Bayesian spam filter); n-gram
#
# semantic: grammer rules, (Name entity identification )
#
# Text Cleaning, (essential the things that are not needed for bag of words)
# stop words: remove the, a ,an
# stemming: chopping, choped are replaced with chop
# lower case conversion:
# remove puntuaction
# Strip extra white spaces
# remove numbers
#
# Sentiment Analysis:
# Detect polarity (postive or negative)
# emotion (sad or happy)
# intent (query, complanint, suggestion)
# which apect of the review: food or ambians etc
# The text could be a review
# Applications:customer service, Social Media
# Appraches: Lexicon based, ML based
#
# Lexicon based: specific to language
# ML based : not very specific to language
#
# Lexicon based:
# Lexions are pre-built (words: sentiment)
# replace the words with sentiment
# apply bag of words, (postive or negative);(sad or happy)
#
# Mentored session:
# Lemmatization,stemming
# BOW: to convert text into numericals
#
# Gen AI:
# First ML-->Structure data-->rows and columns
# Deep Learning--> Unstructure data(text, videos, audio)
# ANN (neurons);CNN(images, videos); RNN(sequence modeling, time based: stock, sales prediction, text)
# inputs to outputs
# image of dog predicted as cat
# neural networks learns gradient decent
# issue with vanishing gradient problem
# to solve, LSTM, forget cell, memory cell
# transformers, encoders and decoders
# Generative AI evovled
#
# List comprehension
#
# why not avg? why normalize,
# what normalize is? two different? ask ChatGPT
# +91-9552518432
