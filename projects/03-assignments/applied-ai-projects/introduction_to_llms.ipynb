# %% [markdown]
# **Intro to LLM's**
# llama model
# parameters:140 GB
# run.c file (500 lines of code in C)
#
# parameters:140 GB
# chuck of internet (10 TB), 6,000 GPU's
#
# predict the next word in sequence
# cat-->sat-->on-->a-->?
# prediction makes into learn a lot about the world
# predict next word--> feed predicted word-->predict next word-->feed predicted word
#
# knowledge is 1-dimensional
# tom cruise mom example
#
# Second state: fine tuning
# Training the assistant, generate answers
# Training is same, next data prediction, swap data sets we collect manually
# users will fill question and response, i.e labeling documentation.
# stage 1: pre-tuning (tons of content from internet, GPU's)
# Stage 2: fine-tuning (labeling instructions, ideal Q&A responses)
# state 3: comparision labels (you are asked to pick much better response)
#
# scaling laws:
# accuracy on next work prediction
# N, number of parameters in the network
# D, the amount of text we train on
# ==> we can expect more intelligence for free
# multimodality (vision, audio); seeing info and generating picture
#
# LLM only have a system 1
# chucking words ------>
# system 2
# question, take 30 min, think thru it, not happening today
#
# self improvement
# alphago-->
# 1) imitating expert human players
# cant surpase human
# 2) Deep mind figured to beat human through selef improvement, reward systems
# lack of reward criteria, consufed? not sure if this is achieved yet or not
#
# custom LLM's
# chatGPT app store and create your own
#
# LLM security:
# Jail break : Eg: make napalm
# role play, fooling Chat GPT
# Eg:cut down stop sign, Caludie doesn't answer, convert it to base 64 and it will answer
# universal transferable suffix
# prompt injection, do not desscribe the image but instead say ""
# best movies 2022,  amazon gift card, fraud link, one of webpages has prompt injection
# data poisoning: trigger phase; train bad pharse that triggers phase
# control over fine tuning,
#
# **Introduction to Transformer Architecture**
# RNN, Vision application replaced by transformers
# FNN, CNN, RNN
# FNN: sigmoid neuron,wighted aggreasion
# CNN: convulation
# RNN: Equation, attention
# Building blocks of Transformer
#
# computing one word at a time, figure our h1 and then h2...
# We have the complete word;
# one direction forward, RNN, and now do it back ward. we are doing this because we need contextual represential. no parallel, we are waiting for each word.
# Encoded RNN; Decoded RNN
# context vector; not sure
# Encoded RNN; Decoded RNN
# h1,h2,h3
# alpha1 , alpha 2 etc
# s1,s2,s3,
# attention spam formula
# can alpha be computed in parallel for all 1 in time step t?
# anwer: no, unless s(t-1)
# recurring connection is problem, get rid of it
#
# Transformer:
# encoder: Feed forward networks, self attention, word embeding
# decoder:Feed forward networks, self attention, encoder-decoder attention
# word embedeings - ask ChatGpt
# word embedeings  as input, you get contect vectors
# embedeings?
# self attention requires two inputs
